# %%
# implement program that take students names, IDs, attendence, quizzes marks, midterm, final, grade
# also for the lab performance, lab exams, attendence
#Created by Mohammed Alfaraj ID: s202323090 and Redha Alturaik ID: s202323010.

# LectureAttendence method
def Lecture_Attendence(num):
    
    while True :
        # open file to read
        attendancefile = open("Lecture_Attendance.txt","r")

        # read the lines
        line = attendancefile.readlines()
        length = len(line)

        # to check if the attendence is took
        FOUND = False


        # columns start from first day
        day = 2

        # variable to take the index of columns
        P = 0

        # save attendence
        attendence_take = ""

        # to select the number want to add or modify the attendance on
        day_attend = 0

        # ask the user to enter Student ID
        SID = input("Enter Student ID: ") # Student ID shortcut

        # while loop to check user input
        if SID == "" :
            break
            
        x = 1
        while x > 0:

            # if not empty stop the loop and start searching about the ID, 
            if SID != "":
                x = 0

                # ask user to select which day want to enter mark
                day_attend = int(input("Select from 1 to 7 days to add attendence: "))

                #check the entered number of day number by the user
                if day_attend == 1:
                    day = 2

                elif day_attend == 2:
                    day = 3

                elif day_attend == 3:
                    day = 4

                elif day_attend == 4:
                    day = 5

                elif day_attend == 5:
                    day = 6

                elif day_attend == 6:
                    day = 7
            
                elif day_attend == 7:
                    day = 8

                else:
                   print("Wrong! Please Select day number")
                   continue

                # loop over the lines to check the Student ID
                for read in line:  

                    # loop over each row in Lecture_Attendence file to check if the ID there
                    for row in range(2,length,2):

                        # loop over the Attendance column
                        for c in range(2,length,2):

                            # if the Student ID found
                            if( SID in line[row].split()):
                            
                                # take the status of attendence now to add or modify
                                attendence_take = line[row].split()[day]
                                FOUND = True
            else:
                break
            
            print(f"Day number {day_attend} The status is: {attendence_take}")

        # Add or modify part
        if FOUND:

            # open Lecture_attendence file to write
            attendancefile = open("Lecture_Attendance.txt","w")

            if attendence_take.isalpha():

                # to ask the user to modify Attendence
                ADD_Modify_Attendence = int(input("Enter 1 to Present, 0 to Absent to Modify: "))
                print()

            else:
                # ask the user to add the attendence
                ADD_Modify_Attendence = int(input("Enter 1 to Present, 0 to Absent to Add: "))
                print()

            # loop over the lines to read and write
            for reads in line:

                # search over that Student ID entered by the user
                for searchs in range(2,length,2):
                
                    # if found Student ID 
                    if SID in reads:
                
                    # the code below is associated with adding and modifying attendance

                        # ------ Day 1 ------ #
                        if day == 2: 
                            P = 0
                            x = reads.split()[P] # name

                            P = 1
                            y = reads.split()[P] # ID

                            P = 3
                            z = reads.split()[P] # 2nd Day

                            P = 4
                            o = reads.split()[P] # 3rd Day

                            P = 5
                            m = reads.split()[P] # 4th Day

                            P = 6
                            s = reads.split()[P] # 5th Day

                            P = 7
                            r = reads.split()[P] # 6th Day

                            P = 8
                            b = reads.split()[P] # 7th Day

                            # Add or modify attendence
                            if ADD_Modify_Attendence == 1:
                                attendence_take = "P"
                            elif ADD_Modify_Attendence == 0:
                                attendence_take = "A"
                            take = ''.join(attendence_take)
                            reads = "%-11s %0s %4.5s %5s %5s %5s %5s %5s %6s"%(x, y, take, z, o, m, s, r, b + "\n")

                            # ------ End ------ #

                        # ------ Day 2 ------ #
                        elif day == 3: 
                            P = 0
                            x = reads.split()[P] # name

                            P = 1
                            y = reads.split()[P] # ID

                            P = 2
                            z = reads.split()[P] # 1st Day

                            P = 4
                            o = reads.split()[P] # 3rd Day

                            P = 5
                            m = reads.split()[P] # 4th Day

                            P = 6
                            s = reads.split()[P] # 5th Day
    
                            P = 7
                            r = reads.split()[P] # 6th Day

                            P = 8
                            b = reads.split()[P] # 7th Day

                            #Add or modify attendence
                            if ADD_Modify_Attendence == 1:
                                attendence_take = "P"
                            elif ADD_Modify_Attendence == 0:
                                attendence_take = "A"
                            take = ''.join(attendence_take)
                            reads = "%-11s %0s %4.5s %5s %5s %5s %5s %5s %6s"%(x, y, z, take, o, m, s, r, b + "\n")

                            # ------ End ------ #

                        # ------ Day 3 ------ #
                        elif day == 4: 
                            P = 0
                            x = reads.split()[P] # name

                            P = 1
                            y = reads.split()[P] # ID

                            P = 2
                            z = reads.split()[P] # 1st Day

                            P = 3
                            o = reads.split()[P] # 2nd Day

                            P = 5
                            m = reads.split()[P] # 4th Day

                            P = 6
                            s = reads.split()[P] # 5th Day

                            P = 7
                            r = reads.split()[P] # 6th Day

                            P = 8
                            b = reads.split()[P] # 7th Day

                            # Add or modify attendence
                            if ADD_Modify_Attendence == 1:
                                attendence_take = "P"
                            elif ADD_Modify_Attendence == 0:
                                attendence_take = "A"
                            take = ''.join(attendence_take)
                            reads = "%-11s %0s %4.5s %5s %5s %5s %5s %5s %6s"%(x, y, z, o, take, m, s, r, b + "\n")

                            # ------ End ------ #

                        # ------ Day 4 ------ #
                        elif day == 5: 
                            P = 0
                            x = reads.split()[P] # name

                            P = 1
                            y = reads.split()[P] # ID

                            P = 2
                            z = reads.split()[P] # 1st Day

                            P = 3
                            o = reads.split()[P] # 2nd Day

                            P = 4
                            m = reads.split()[P] # 3rd Day

                            P = 6
                            s = reads.split()[P] # 5th Day

                            P = 7
                            r = reads.split()[P] # 6th Day

                            P = 8
                            b = reads.split()[P] # 7th Day

                            # Add or modify attendence
                            if ADD_Modify_Attendence == 1:
                                attendence_take = "P"
                            elif ADD_Modify_Attendence == 0:
                                attendence_take = "A"
                            take = ''.join(attendence_take)
                            reads = "%-11s %0s %4.5s %5s %5s %5s %5s %5s %6s"%(x, y, z, o, m, take, s, r, b + "\n")

                            # ------ End ------ #

                        # ------ Day 5 ------ #
                        elif day == 6: 
                            P = 0
                            x = reads.split()[P] # name

                            P = 1
                            y = reads.split()[P] # ID

                            P = 2
                            z = reads.split()[P] # 1st Day

                            P = 3
                            o = reads.split()[P] # 2nd Day

                            P = 4
                            m = reads.split()[P] # 3rd Day

                            P = 5
                            s = reads.split()[P] # 4th Day

                            P = 7
                            r = reads.split()[P] # 6th Day

                            P = 8
                            b = reads.split()[P] # 7th Day

                            #modify or modify attendence
                            if ADD_Modify_Attendence == 1:
                                attendence_take = "P"
                            elif ADD_Modify_Attendence == 0:
                                attendence_take = "A"
                            take = ''.join(attendence_take)
                            reads = "%-11s %0s %4.5s %5s %5s %5s %5s %5s %6s"%(x, y, z, o, m, s, take, r, b + "\n")

                            # ------ End ------ #

                        # ------ Day 6 ------ #
                        elif day == 7: 
                            P = 0
                            x = reads.split()[P] # name

                            P = 1
                            y = reads.split()[P] # ID

                            P = 2
                            z = reads.split()[P] # 1st Day

                            P = 3
                            o = reads.split()[P] # 2nd Day

                            P = 4
                            m = reads.split()[P] # 3rd Day

                            P = 5
                            s = reads.split()[P] # 4th Day

                            P = 5
                            r = reads.split()[P] # 5th Day

                            P = 8
                            b = reads.split()[P] # 7th Day
    
                            # Add or modify attendence
                            if ADD_Modify_Attendence == 1:
                                attendence_take = "P"
                            elif ADD_Modify_Attendence == 0:
                                attendence_take = "A"
                            take = ''.join(attendence_take)
                            reads = "%-11s %0s %4.5s %5s %5s %5s %5s %5s %6s"%(x, y, z, o, m, s, r, take, b + "\n")

                            # ------ End ------ #

                        # ------ Day 7 ------ #
                        elif day == 8: 
                            P = 0
                            x = reads.split()[P] # name

                            P = 1
                            y = reads.split()[P] # ID

                            P = 2
                            z = reads.split()[P] # 1st Day

                            P = 3
                            o = reads.split()[P] # 2nd Day

                            P = 4
                            m = reads.split()[P] # 3rh Day

                            P = 5
                            s = reads.split()[P] # 4th Day

                            P = 6
                            r = reads.split()[P] # 5th Day
    
                            P = 7
                            b = reads.split()[P] # 6th Day

                            # Add or modify attendence
                            if ADD_Modify_Attendence == 1:
                                attendence_take = "P"
                            elif ADD_Modify_Attendence == 0:
                                attendence_take = "A"
                            take = ''.join(attendence_take)
                            reads = "%-11s %0s %4.5s %5s %5s %5s %5s %5s %6s"%(x, y, z, o, m, s, r, b, take + "\n")

                            # ------ End ------ #



                attendancefile.write(reads)
                #print(reads)
            attendancefile.close()
        
# quizzes method to take the best 4 quizzes
def Quizzes(num):
    while True :
        # open Quizzes file to read
        openfile = open("Quizzes.txt","r")

        # read lines inside file
        lines = openfile.readlines()
        length = len(lines)

        # variable to save the mark
        mark = ""

        # save row and columns
        keep = ""

        #number of columns
        P = 0

        # sum of best four quizzes
        sum = 0

        # col to specify each column for each quiz number
        col = 0

        # to check if the mark is took
        FOUND = False

        # ask the user to enter Student ID
        SID = input("Enter Student ID: ")

        # while loop to check user input
        if SID == "" :
            break
            
        x = 1
        while x > 0:

            # if not emplty stop the loop and start searching about the ID, and take its Quiz mark selected
            if SID != "":

                x = 0

                # ask user to select which quiz want to enter mark
                Quiz_Number = int(input("Enter 1 to add Quiz1 mark, 2 for Quiz2, 3 for Quiz3, 4 for Quiz4, 5 for Quiz5: "))

                #check the entered number of Quiz number by the user
                if Quiz_Number == 1:
                    col = 2

                elif Quiz_Number == 2:
                    col = 3

                elif Quiz_Number == 3:
                    col = 4

                elif Quiz_Number == 4:
                    col = 5

                elif Quiz_Number == 5:
                    col = 6

                else:
                   print("Wrong! Please Select number")
                   continue

                # loop over the lines to check the Student ID
                for read in lines:  

                    # loop over each row in quizzes file to check if the ID there
                    for row in range(2,length,2):

                        # loop over the quiz column
                        for c in range(2,length,2):

                            # if the Student ID found
                            if( SID in lines[row].split()):
                            
                                # take the mark now to add or modify
                                mark = lines[row].split()[col]
                                FOUND = True
            else:
                x = 0
                break

        print(f"Quiz Number is: {Quiz_Number} The mark is: {mark}")

        # start add or modify part
        if FOUND:
            # to save the Best 4 quizzes out of 15%
            Quizzes_mark = 0 
            Best_4_Marks = []
            # open Quizzes file to write
            openfile = open("Quizzes.txt","w")

            if mark.isdigit():
                # to ask the user to modify
                ADD_Modify_Mark = input("Enter the mark you want to Modify: ")
                print()
            else:
                # ask to input the mark
                ADD_Modify_Mark = input("Enter the mark you want to Add: ")
                print()

            # loop over the lines to read and write
            for reading in lines:

                # search over that Student ID entered by the user
                for searching in range(2,length,2):
                
                    # if found Student ID 
                    if SID in reading:
                        
                        #check for the input entered
                        if ADD_Modify_Mark.isdigit():

                            # ------ Quiz 1 ------
                            if col == 2: 
                                P = 0
                                x = reading.split()[P] # name
    
                                P = 1
                                y = reading.split()[P] # ID

                                P = 3
                                z = reading.split()[P] # Second Quiz

                                P = 4
                                o = reading.split()[P] # third Quiz

                                P = 5
                                m = reading.split()[P] # fourth Quiz

                                P = 6
                                u = reading.split()[P] # Fifth Quiz

                                P = 7
                                s = reading.split()[P] # best Quizzes

                                #modify the mark

                                mark = ADD_Modify_Mark
                                take = ''.join(mark)
                                reading = "%-11s %0s %5.5s %7s %7s %7s %7s %11s"%(x, y, take, z, o, m, u, s + "\n")

                                # ------ End ------

                            # ------ Quiz 2 ------
                            elif col == 3: # Quiz 2

                                P = 0
                                x = reading.split()[P] # name

                                P = 1
                                y = reading.split()[P] # ID

                                P = 2
                                z = reading.split()[P] # First Quiz

                                P = 4
                                o = reading.split()[P] # third Quiz

                                P = 5
                                m = reading.split()[P] # fourth Quiz

                                P = 6
                                u = reading.split()[P] # Fifth Quiz
    
                                P = 7
                                s = reading.split()[P] # best Quizzes

                                #modify the mark

                                mark = ADD_Modify_Mark
                                take = ''.join(mark)
                                reading = "%-11s %0s %5.5s %7s %7s %7s %7s %11s"%(x, y, z, take, o, m, u, s + "\n")

                                # ------ End ------

                            # ------ Quiz 3 ------
                            elif col == 4: # Quiz 3

                                P = 0
                                x = reading.split()[P] # name

                                P = 1
                                y = reading.split()[P] # ID

                                P = 2
                                z = reading.split()[P] # First Quiz

                                P = 3
                                o = reading.split()[P] # Second Quiz

                                P = 5
                                m = reading.split()[P] # fourth Quiz

                                P = 6
                                u = reading.split()[P] # Fifth Quiz

                                P = 7
                                s = reading.split()[P] # best Quizzes

                                #modify the mark

                                mark = ADD_Modify_Mark
                                take = ''.join(mark)
                                reading = "%-11s %0s %5.5s %7s %7s %7s %7s %11s"%(x, y, z, o, take, m, u, s + "\n")
    
                                # ------ End ------

                            # ------ Quiz 4 ------
                            elif col == 5: # Quiz 4

                                P = 0
                                x = reading.split()[P] # name

                                P = 1
                                y = reading.split()[P] # ID

                                P = 2
                                z = reading.split()[P] # First Quiz

                                P = 3
                                o = reading.split()[P] # Second Quiz

                                P = 4
                                m = reading.split()[P] # Third Quiz

                                P = 6
                                u = reading.split()[P] # Fifth Quiz
    
                                P = 7
                                s = reading.split()[P] # best Quizzes

                                #modify the mark

                                mark = ADD_Modify_Mark
                                take = ''.join(mark)
                                reading = "%-11s %0s %5.5s %7s %7s %7s %7s %11s"%(x, y, z, o, m, take, u, s + "\n")

                                # ------ End ------
    
                            # ------ Quiz 5 ------ 
                            elif col == 6: # Quiz 5
                                P = 0
                                x = reading.split()[P] # name

                                P = 1
                                y = reading.split()[P] # ID

                                P = 2
                                z = reading.split()[P] # First Quiz

                                P = 3
                                o = reading.split()[P] # Second Quiz

                                P = 4
                                m = reading.split()[P] # Third Quiz
    
                                P = 5
                                u = reading.split()[P] # Fourth Quiz

                                P = 7
                                s = reading.split()[P] # best Quizzes

                                #modify the mark

                                mark = ADD_Modify_Mark
                                take = ''.join(mark)
                                reading = "%-11s %0s %5.5s %7s %7s %7s %7.5s %7.5s"%(x, y, z,  o, m, u, take, s + "\n")
                            
                                # ------ End ------

        
                openfile.write(reading)
                #print(reading)
  
            openfile.close()

        # --------------- Quizzes part ---------------#

            #open Quizzes file
            infile = open("Quizzes.txt","r")

            # to read over the lines
            line = infile.readlines()
            Found = False
            length = len(line)

            # list to save the marks
            Quiz_s = []

            # loop over the lines to take the marks
            for read in line:
                for xe in range(2,length):
                    for ue in range(0,length,1):
                        if SID in read:
                            Quiz1 = read.split()[2]
                            Quiz2 = read.split()[3]
                            Quiz3 = read.split()[4]
                            Quiz4 = read.split()[5]
                            Quiz5 = read.split()[6]
                            Found = True

            # add them to the list
            Quiz_s.append(int(Quiz1))
            Quiz_s.append(int(Quiz2))
            Quiz_s.append(int(Quiz3))
            Quiz_s.append(int(Quiz4))
            Quiz_s.append(int(Quiz5))

        # if take the grade
        if Found:
        
            # to save best 4 Quizzes mark
            calc = 0

            # find the best 4 quizzes
            Minimum_Quiz = min(Quiz_s)
            Quiz_s.remove(Minimum_Quiz)
            print("Best 4 Quizzes are: ",Quiz_s)

            # find the grade out of 15% for the best 4 quizzes
            for best in range(0,4):
                calc = Quiz_s[best]
                Quizzes_mark += calc
            Quizzes_mark = (Quizzes_mark / 400) * 15 # to take the best 4 Quizzes out of 15%

        print(f"The Quiz mark out of 15 is: {Quizzes_mark}/15")
        best4quizzes = str(round(Quizzes_mark,2))

        Found = False
        # open the file to read
        Quizfile = open("Quizzes.txt","r")

        # take the value of the best quizzes
        for looks in line:

            for row in range(2,length,2):

                for col in range(0,length,1):

                    if SID in line[row].split():
                        quizgrade = line[row].split()[7]
                        Found = True
        if Found:

            # open the file to write
            Quizfile = open("Quizzes.txt","w")
    

            # loop over the lines to print the best 4 quizzes mark
            for look in line:

                for search in range(2,length,2):

                    if SID in look:

                        p = 0
                        xx = look.split()[p]

                        p = 1
                        yy = look.split()[p]

                        p = 2
                        zz = look.split()[p]

                        p = 3
                        rr = look.split()[p]
    
                        p = 4
                        ii = look.split()[p]

                        p = 5
                        tt = look.split()[p]

                        p = 6
                        ss = look.split()[p]

                        # add the best 4

                        quizgrade = best4quizzes
                        finalquizcheck = ''.join(quizgrade)
                        look = "%-11s %0s %4.5s %7s %7s %7s %7.5s %8.9s"%(xx,yy,zz,rr,ii,tt,ss,finalquizcheck+"\n")

                Quizfile.write(look)
                #print(look)
            Quizfile.close()
    
def Lab_project():
    
    while True : 
        #Save all lines in a variable
        infile = open("Lab_Marks.txt", "r")
        lines = infile.readlines()
        infile.close
        ID = input("Enter student ID: ")
        
        #Check if ID exists, if user enters nothing leave the function.
        if ID == "" :
            break
        ID_found = False
        linenum = 0
        
        #Search for the row with the student ID.
        for e in lines :
            if ID in e :
                ID_found = True
                break
            linenum += 1
        
        #If student ID is found
        if ID_found and len(ID) == 10 :
            
            mark = 0        
            while True :
                
                #Ask user to enter the mark.
                mark = input("Enter project mark: ")
                
                #Check if entered mark is from 0 to 100.
                if not mark.isdigit() :
                    print("Enter integer numbers only")
                    
                elif int(mark) >= 0 and int(mark) <= 100 :
                    break
                    
                else : 
                    print("Marks can only be from 0 to 100")
            
            #Position in the file where the mark would be entered
            position = 63
                
            line = lines[linenum]
            change = ""
            
            #Checks the length of the mark then adds the mark to the row with the student ID saved in a variable.
            if len(mark) == 2 :
                mark =  " " + mark
            
            elif len(mark) == 1 :
                mark = " " + mark + " "
                
            change = line[0 : position-1] + mark + line[position + 2 :]
            
            #add the changes to the files with the other records.
            outfile = open("Lab_Marks.txt", "w")            
            i = 0
            for e in lines :
                    #Adds all the lines normally until reaching the one with the studentID modified, which will add the new one with the mark.
                    if i == linenum :
                        outfile.write(change)
                    else :
                        outfile.write(e)
                    i += 1
            outfile.close()
            
        else :
            print("ID not found") 
    
# lab attendence method 
def Lab_Attendance(number):
    while True :
    
        # open file to read
        attendfile = open("Lab_Attendence.txt","r")

        # read the lines
        line = attendfile.readlines()
        length = len(line)

        # to check if the attendence is took
        FOUND = False


        # columns start from first day
        day = 2

        # save attendence
        attendence_take = ""
        # ask the user to enter Student ID
        SID = input("Enter Student ID: ")

        # while loop to check user input
        if SID == "" :
            break
            
        x = 1
        while x > 0:

            # if not empty stop the loop and start searching about the ID, 
            if SID != "":
                x = 0

                # ask user to select which day want to enter mark
                day_attend = int(input("select from 1 to 4 days to add attendence: "))

                #check the entered number of day number by the user
                if day_attend == 1:
                    day = 2

                elif day_attend == 2:
                    day = 3

                elif day_attend == 3:
                    day = 4

                elif day_attend == 4:
                    day = 5

                else:
                   print("Wrong! Please Select day number")
                   continue

                # loop over the lines to check the Student ID
                for read in line:  

                    # loop over each row in Lab_Attendence file to check if the ID there
                    for row in range(2,length,2):

                        # loop over the quiz column
                        for c in range(2,length,2):

                            # if the Student ID found
                            if( SID in line[row].split()):
                            
                                # take the status of attendence now to add or modify
                                attendence_take = line[row].split()[day]
                                FOUND = True
            else:
                x = 0
                break

        print(f"Day number {day_attend} The status is: {attendence_take}")

        # start add or modify part
        if FOUND:

            # open lab_attendence file to write
            attendfile = open("Lab_Attendence.txt","w")

            if attendence_take.isalpha():

                # to ask the user to modify Attendence
                ADD_Modify_Attendence = int(input("Enter 1 to Present, 0 to Absent to Modify: "))
                print()

            else:
                # ask the user to add the attendence
                ADD_Modify_Attendence = int(input("Enter 1 to Present, 0 to Absent to Add: "))
                print()

            # loop over the lines to read and write
            for reads in line:

                # search over that Student ID entered by the user
                for searchs in range(2,length,2):
                
                    # if found Student ID 
                    if SID in reads:
                
                        # ------ Day 1 ------ #
                        if day == 2: 
                            P = 0
                            x = reads.split()[P] # name

                            P = 1
                            y = reads.split()[P] # ID

                            P = 3
                            z = reads.split()[P] # Second Day

                            P = 4
                            o = reads.split()[P] # third Day

                            P = 5
                            m = reads.split()[P] # fourth Day

                            #modify or modify attendence
                            if ADD_Modify_Attendence == 1:
                                attendence_take = "P"
                            elif ADD_Modify_Attendence == 0:
                                attendence_take = "A"
                            take = ''.join(attendence_take)
                            reads = "%-11s %0s %4.5s %5s %5s %6s"%(x, y, take, z, o, m + "\n")

                            # ------ End ------ #

                        # ------ Day 2 ------ #
                        elif day == 3: 
                            P = 0
                            x = reads.split()[P] # name

                            P = 1
                            y = reads.split()[P] # ID

                            P = 2
                            z = reads.split()[P] # First Day

                            P = 4
                            o = reads.split()[P] # third Day

                            P = 5
                            m = reads.split()[P] # fourth Day

                            # modify or add attendence
                            if ADD_Modify_Attendence == 1:
                                attendence_take = "P"

                            elif ADD_Modify_Attendence == 0:
                                attendence_take = "A"


                            take = ''.join(attendence_take)
                            reads = "%-11s %0s %4.5s %5s %5s %6s"%(x, y, z, take, o, m + "\n")

                            # ------ End ------

                        # ------ Day 3 ------ #
                        elif day == 4: 
                            P = 0
                            x = reads.split()[P] # name

                            P = 1
                            y = reads.split()[P] # ID

                            P = 2
                            z = reads.split()[P] # First Day

                            P = 3
                            o = reads.split()[P] # Second Day

                            P = 5
                            m = reads.split()[P] # fourth Day

                            #modify or add attendence
                            if ADD_Modify_Attendence == 1:
                                attendence_take = "P"
                            elif ADD_Modify_Attendence == 0:
                                attendence_take = "A"
                            take = ''.join(attendence_take)
                            reads = "%-11s %0s %4.5s %5s %5s %6s"%(x, y, z, o, take, m + "\n")

                            # ------ End ------

                        # ------ Day 4 ------ #
                        elif day == 5: 
                            P = 0
                            x = reads.split()[P] # name

                            P = 1
                            y = reads.split()[P] # ID

                            P = 2
                            z = reads.split()[P] # First Day

                            P = 3
                            o = reads.split()[P] # Second Day

                            P = 4
                            m = reads.split()[P] # Third Day

                            #modify or add attendence
                            if ADD_Modify_Attendence == 1:
                                attendence_take = "P"
                            elif ADD_Modify_Attendence == 0:
                                attendence_take = "A"
                            take = ''.join(attendence_take)
                            reads = "%-11s %0s %4.5s %5s %5s %6s"%(x, y, z, o, m , take + "\n")

                            # ------ End ------


                attendfile.write(reads)
                #print(reads)
            attendfile.close()

# homework assignment method
def Homework_Assignments() : 
    
    #Save all lines in a variable
    while True : 
        infile = open("Marks.txt", "r")
        lines = infile.readlines()
        infile.close
        ID = input("Enter student ID: ")
        
        #Check if ID exists, if user enters nothing leave the function.
        if ID == "" :
            break
        ID_found = False
        linenum = 0
        
        #Search for the row with the student ID.
        for e in lines :
            if ID in e :
                ID_found = True
                break
            linenum += 1
            
        #If student ID is found  
        if ID_found and len(ID) == 10 :
            num = 0
            while True:
                
                #Ask user to enter a homework number and the mark.
                num = input("Enter Homework number: ")
                
                #Check if homework number is from 1 to 4.
                if not num.isdigit() :
                    print("Enter numbers only")
                    
                elif int(num) >= 1 and int(num) <= 4 :
                    break
                    
                else :
                    print("There are only 4 homeworks")
            
            mark = 0        
            while True :
                #Check if entered mark is from 0 to 100.
                mark = input("Enter mark: ")
                
                if not mark.isdigit() :
                    print("Enter integer numbers only")
                    
                elif int(mark) >= 0 and int(mark) <= 100 :
                    break
                    
                else : 
                    print("Marks can only be from 0 to 100")
            
            #Positions in the file where the mark would be entered
            position = 0
            if num == "1" :
                position = 27
            elif num == "2" :
                position = 33
            elif num == "3" :
                position = 39
            elif num == "4" :
                position = 45
                
            line = lines[linenum]
            change = ""
            
            #Checks the length of the mark then adds the mark to the row with the student ID saved in a variable.
            if len(mark) == 2 :
                mark =  " " + mark
            
            elif len(mark) == 1 :
                mark = " " + mark + " "
                
            change = line[0 : position-1] + mark + line[position + 2 :]
            
            #add the changes to the files with the other records.
            outfile = open("Marks.txt", "w")            
            i = 0
            for e in lines :
                    
                    #Adds all the lines normally until reaching the one with the studentID modified, which will add the new one with the mark.
                    if i == linenum :
                        outfile.write(change)
                    else :
                        outfile.write(e)
                    i += 1
            outfile.close()
                
        else :
            print("ID not found")
    
 
def Midterm_Exam() :  
    
    while True : 
        #Save all lines in a variable
        infile = open("Marks.txt", "r")
        lines = infile.readlines()
        infile.close
        ID = input("Enter student ID: ")
        
        #Check if ID exists, if user enters nothing leave the function.
        if ID == "" :
            break
        ID_found = False
        linenum = 0
        
        #Search for the row with the student ID.
        for e in lines :
            if ID in e :
                ID_found = True
                break
            linenum += 1
        
        #If student ID is found
        if ID_found and len(ID) == 10 :
            
            mark = 0        
            while True :
                #Ask user to enter the mark.
                mark = input("Enter mark: ")
                
                #Check if entered mark is from 0 to 100.
                if not mark.isdigit() :
                    print("Enter integer numbers only")
                    
                elif int(mark) >= 0 and int(mark) <= 100 :
                    break
                    
                else : 
                    print("Marks can only be from 0 to 100")
            
            #Position in the file where the mark would be entered
            position = 51
                
            line = lines[linenum]
            change = ""
            
            #Checks the length of the mark then adds the mark to the row with the student ID saved in a variable.
            if len(mark) == 2 :
                mark =  " " + mark
            
            elif len(mark) == 1 :
                mark = " " + mark + " "
                
            change = line[0 : position-1] + mark + line[position + 2 :]
            
            #add the changes to the files with the other records.
            outfile = open("Marks.txt", "w")            
            i = 0
            for e in lines :
                    #Adds all the lines normally until reaching the one with the studentID modified, which will add the new one with the mark.
                    if i == linenum :
                        outfile.write(change)
                    else :
                        outfile.write(e)
                    i += 1
            outfile.close()
                
        else :
            print("ID not found")
    
def Final_Exam() :
    
    while True : 
        #Save all lines in a variable
        infile = open("Marks.txt", "r")
        lines = infile.readlines()
        infile.close
        ID = input("Enter student ID: ")
        
        #Check if ID exists, if user enters nothing leave the function.
        if ID == "" :
            break
        ID_found = False
        linenum = 0
        
        #Search for the row with the student ID.
        for e in lines :
            if ID in e :
                ID_found = True
                break
            linenum += 1
        
        #If student ID is found
        if ID_found and len(ID) == 10 :
            
            mark = 0        
            while True :
                
                #Ask user to enter the mark.
                mark = input("Enter mark: ")
                
                #Check if entered mark is from 0 to 100.
                if not mark.isdigit() :
                    print("Enter integer numbers only")
                    
                elif int(mark) >= 0 and int(mark) <= 100 :
                    break
                    
                else : 
                    print("Marks can only be from 0 to 100")
            
            #Position in the file where the mark would be entered
            position = 57
                
            line = lines[linenum]
            change = ""
            
            #Checks the length of the mark then adds the mark to the row with the student ID saved in a variable.
            if len(mark) == 2 :
                mark =  " " + mark
            
            elif len(mark) == 1 :
                mark = " " + mark + " "
                
            change = line[0 : position-1] + mark + line[position + 2 :]
            
            outfile = open("Marks.txt", "w")            
            i = 0
            #add the changes to the files with the other records.
            for e in lines :
                    #Adds all the lines normally until reaching the one with the studentID modified, which will add the new one with the mark.
                    if i == linenum :
                        outfile.write(change)
                    else :
                        outfile.write(e)
                    i += 1
            outfile.close()

def Lab_Work() :
    
    while True : 
        #Save all lines in a variable
        infile = open("Lab_Marks.txt", "r")
        lines = infile.readlines()
        infile.close
        ID = input("Enter student ID: ")
        
        #Check if ID exists, if user enters nothing leave the function.
        if ID == "" :
            break
        ID_found = False
        linenum = 0
        
        #Search for the row with the student ID.
        for e in lines :
            if ID in e :
                ID_found = True
                break
            linenum += 1
        
        #If student ID is found
        if ID_found and len(ID) == 10 :
            num = 0
            while True:
                #Ask user to enter the lab number, limit 4 labs.
                num = input("Enter Lab number: ")               
                
                if not num.isdigit() :
                    print("Enter numbers only")
                    
                elif int(num) >= 1 and int(num) <= 4 :
                    break
                    
                else :
                    print("There are only 4 labs")
            
            mark = 0 
            #Ask user to enter the mark.
            while True :
                mark = input("Enter mark: ")
                
                #Check if entered mark is from 0 to 100.
                if not mark.isdigit() :
                    print("Enter integer numbers only")
                    
                elif int(mark) >= 0 and int(mark) <= 100 :
                    break
                    
                else : 
                    print("Marks can only be from 0 to 100")
            
            #Positions in the file where the mark would be entered
            position = 0
            if num == "1" :
                position = 27
            elif num == "2" :
                position = 33
            elif num == "3" :
                position = 39
            elif num == "4" :
                position = 45
                
            line = lines[linenum]
            change = ""
            
            #Checks the length of the mark then adds the mark to the row with the student ID saved in a variable.
            if len(mark) == 2 :
                mark =  " " + mark
            
            elif len(mark) == 1 :
                mark = " " + mark + " "
                
            change = line[0 : position-1] + mark + line[position + 2 :]
            
            #add the changes to the files with the other records.
            outfile = open("Lab_Marks.txt", "w")            
            i = 0
            for e in lines :
                    #Adds all the lines normally until reaching the one with the studentID modified, which will add the new one with the mark.
                    if i == linenum :
                        outfile.write(change)
                    else :
                        outfile.write(e)
                    i += 1
            outfile.close()
                
        else :
            print("ID not found")

def Lab_Exam() :
    
    while True : 
        #Save all lines in a variable
        infile = open("Lab_Marks.txt", "r")
        lines = infile.readlines()
        infile.close
        ID = input("Enter student ID: ")
        
        #Check if ID exists, if user enters nothing leave the function.
        if ID == "" :
            break
        ID_found = False
        linenum = 0
        
        #Search for the row with the student ID.
        for e in lines :
            if ID in e :
                ID_found = True
                break
            linenum += 1
         
        #If student ID is found
        if ID_found and len(ID) == 10 :
            num = 0
            while True:
                #Ask user to enter the lab exam number from 1 to 2.
                num = input("Enter Lab Exam number: ")
                
                #Check if entered lab exam number is from correct.
                if not num.isdigit() :
                    print("Enter numbers only")
                    
                elif int(num) >= 1 and int(num) <= 2 :
                    break
                    
                else :
                    print("There are only 2 lab exams")
            
            mark = 0 
            
            #Ask user to enter the mark.
            while True :
                mark = input("Enter mark: ")
                
                #Check if entered mark is from 0 to 100.
                if not mark.isdigit() :
                    print("Enter integer numbers only")
                    
                elif int(mark) >= 0 and int(mark) <= 100 :
                    break
                    
                else : 
                    print("Marks can only be from 0 to 100")
            
            #Position in the file where the mark would be entered
            position = 0
            if num == "1" :
                position = 51
            elif num == "2" :
                position = 57
                
            line = lines[linenum]
            change = ""
            
            #Checks the length of the mark then adds the mark to the row with the student ID saved in a variable.
            if len(mark) == 2 :
                mark =  " " + mark
            
            elif len(mark) == 1 :
                mark = " " + mark + " "
                
            change = line[0 : position-1] + mark + line[position + 2 :]
            
            #add the changes to the files with the other records.
            outfile = open("Lab_Marks.txt", "w")            
            i = 0
            for e in lines :
                    #Adds all the lines normally until reaching the one with the studentID modified, which will add the new one with the mark.
                    if i == linenum :
                        outfile.write(change)
                    else :
                        outfile.write(e)
                    i += 1
            outfile.close()
                
        else :
            print("ID not found")

# to open new file Contains, Student' ID, Name, marks ( from highest to lowest)
def getGrade():
    #Create a separate file containing students’ id, name and marks (from highest to lowest)


    # --------------- Lab Exam part ---------------#

    # open lab test file to take the marks
    Labfile = open("Lab_Marks.txt","r")

    # read the marks of lab_exam
    line = Labfile.readlines()

    # the sum of all marks
    sum = 0

    # to receive the final mark
    lab = 0

    # to save the lab exam mark
    data = ""

    # to take the mark and do multiplication
    lab_mark = 0

    # list to save students
    Students = []

    lab_ex = []
    Student_ID = input("Enter Student ID: ")

    Found = False

    # read over the lines in the file
    for read in line:

        # loop over the rows in file
        for row in range(1,5,1):

            # loop over the columns in file
            for col in range(1,5,1):

                #check if the ID exist 
                if Student_ID in line[row].split():
                    studentname = line[row].split()[0]
                    studentid = line[row].split()[1]
                    lab1 = line[row].split()[6]
                    lab2 = line[row].split()[7]
                    Found = True
        
    Students.append(studentname)
    Students.append(studentid)
    lab_ex.append(lab1)
    lab_ex.append(lab2)

    # if Found the grade
    if Found:
        
        # take the lab grades from the list
        for i in range(0,2):
            data = lab_ex[i]
            lab_mark = int(data)
            lab = lab + (lab_mark / 100) * 6 # the grade will take is out of 12%
            

    # --------------- Lab work part ---------------#

    lab_grades = []

    # read over the lines in the file
    for read in line:

        # loop over the rows in file
        for row in range(1,5,1):

            # loop over the columns in file
            for col in range(1,5,1):

                # check if the ID exist take the lab work grades
                if Student_ID in line[row].split():
                    lab1 = line[row].split()[2]
                    lab2 = line[row].split()[3]
                    lab3 = line[row].split()[4]
                    lab4 = line[row].split()[5]
                    Found = True
                    
    # add them to the list
    lab_grades.append(lab1)
    lab_grades.append(lab2)
    lab_grades.append(lab3)
    lab_grades.append(lab4)

    # if Found the grade
    if Found:
        
        # reassign zero to lab_marks
        lab_mark = 0
        
        # take the lab grades then divide and mulitply it by the percent 
        for i in range(0,4):
            data = lab_grades[i]
            lab_mark = lab_mark + int(data)
            
        lab = lab + (lab_mark / 400) * 3 # the grade will take is out of 3% for labwork

    # remove lab_exam grades from the Student list
    #Students.remove(lab1)
    #Students.remove(lab2)

    #add the lab grade to sum
    sum += round(lab,1)

    # --------------- Lab Project part ---------------#
    # to take the grade to the list
    lab_project = []

    take_grade = 0
    # read over the lines in the file
    for read in line:

        # loop over the rows in file
        for row in range(1,6,1):

            # loop over the columns in file
            for col in range(1,6,1):

                # check if the ID exist take the lab work grades
                if Student_ID in line[row].split():
                    lab_p = line[row].split()[8]
                    Found = True
                    
    # add them to the list
    lab_project.append(lab_p)
    # if Found the grade
    if Found:

            take_grade = int(lab_p)
            labtakegrade = (take_grade / 100) * 5 # lab project out of 5%

    sum += round(labtakegrade,2)
    Labfile.close()
    # --------------- Homework part ---------------#

    #open homework file
    homeworkfile = open("Marks.txt","r")

    #read the lines
    homeworklines = homeworkfile.readlines()

    # to do calculation
    homework_marks = 0

    # list to save homework marks
    homeworklist = []

    # to receive final mark
    homework = 0

    Found = False

    # read over the lines in the file
    for read in homeworklines:

        # loop over the rows in file
        for row in range(1,5,1):

            # loop over the columns in file
            for col in range(1,5,1):

                #check if the ID exist, take the home work marks
                if Student_ID in homeworklines[row].split():
                    HW1 = homeworklines[row].split()[4]
                    HW2 = homeworklines[row].split()[6]
                    HW3 = homeworklines[row].split()[8]
                    HW4 = homeworklines[row].split()[10]
                    Found = True
                    
    # add each mark to the list
    homeworklist.append(HW1)
    homeworklist.append(HW2)
    homeworklist.append(HW3)
    homeworklist.append(HW4)

    # if Found the grade
    if Found:
        
        # loop over each HW to take the mark
        for m in range(4):
            data = homeworklist[m]
            homework_marks += int(data)
        homework = (homework_marks / 400) * 5 # homeworks grade out of 5%

    # add the mark to the sum
    sum = sum + round(homework,2)

    homeworkfile.close()

    # --------------- Quizzes part ---------------#

    # open Quizzes file
    Quizfile = open("Quizzes.txt","r")

    # to read over the lines
    bestline = Quizfile.readlines()

    # to save the 5 quizzes mark
    Best_4_Marks = []
    Found = False
    Quizzes_mark = 0
    # read over the lines in the file
    for look in bestline:

        # loop over the rows in file
        for row in range(1,6,1):

            # loop over the columns in file
            for col in range(1,6,1):

                #check if the ID exist 
                if Student_ID in bestline[row].split():
                    Quiz1 = bestline[row].split()[2]
                    Quiz2 = bestline[row].split()[3]
                    Quiz3 = bestline[row].split()[4]
                    Quiz4 = bestline[row].split()[5]
                    Quiz5 = bestline[row].split()[6]
                    Found = True

    # add the marks in the list
    Best_4_Marks.append(int(Quiz1))
    Best_4_Marks.append(int(Quiz2))
    Best_4_Marks.append(int(Quiz3))
    Best_4_Marks.append(int(Quiz4))
    Best_4_Marks.append(int(Quiz5))

    # if Found the grade
    if Found:
        # to save best 4 Quizzes mark
        calc = 0

        # find the best 4 quizzes
        Minimum_Quiz = min(Best_4_Marks)
        Best_4_Marks.remove(Minimum_Quiz)

        # find the grade out of 15% for the best 4 quizzes
        for best in range(0,4):
            calc = Best_4_Marks[best]
            Quizzes_mark += calc
        Quizzes_mark = (Quizzes_mark / 400) * 15 # to take the best 4 Quizzes out of 15%

    sum += round(Quizzes_mark,2)
    Quizfile.close()

    # --------------- Mid term part ---------------#

    # open file to read
    Midfile = open("Marks.txt","r")

    # read over the lines
    Mid_line = Midfile.readlines()

    # to convert from string to int and do calculation
    Mid_mark = 0

    # to receive the mark and add it the sum
    Midterm = 0

    # list to add the mark in
    Mid = []

    Found = False

    # read over the lines in the file
    for read in Mid_line:

        # loop over the rows in file
        for row in range(1,5,1):

            # loop over the columns in file
            for col in range(1,5,1):

                #check if the ID exist, take the midterm mark
                if Student_ID in Mid_line[row].split():
                    Midterm_grade = Mid_line[row].split()[12]
                    Found = True
                    
    # add it to the list
    Mid.append(Midterm_grade)

    # if Found the grade 
    if Found:
        
        # convert the mark to integer
        Mid_mark = int(Midterm_grade)
        Midterm = (Mid_mark / 100) * 30 # Midterm exam is out of 30%

    # add the grade to the sum
    sum += Midterm
    Midfile.close()

    # --------------- final exam part ---------------#
    # open file to read
    finalfile = open("Marks.txt","r")

    # read the line for the mark
    final_line = finalfile.readlines()

    # to convert from string to int and do calculation
    Final_mark = 0

    # to receive the mark and add it the sum
    Final = 0

    # list to add the mark in
    Final_list = []
    Found = False

    # read over the lines in the file
    for read in final_line:

        # loop over the rows in file
        for row in range(1,5,1):

            # loop over the columns in file
            for col in range(1,5,1):

                #check if the ID exist, take the Final mark
                if Student_ID in final_line[row].split():
                    Final_grade = final_line[row].split()[14]
                    Found = True
                    
    # add it to the list
    Final_list.append(Final_grade)
    # if Found the grade
    if Found:
        
        Final_mark = int(Final_grade)
        Final = (Final_mark / 100) * 30 # the Final is out of 30% 
        
    # add the grade to the sum
    sum += Final

    #print the result
    Students.append(str(sum))
    print(Students)
    finalfile.close()

#Calculates the marks for all students
def Grades() :
    
    #Variables to store marks and students with best scores
    finalmarks = []
    Beststudents = []
    allmarks = []
    studentmark = []
    
    #Save all lines from marks file which include homeworks, mid, and final in a variable
    infile = open("Marks.txt", "r")
    lines = infile.readlines()
    infile.close()
    
    i = 0
    #Loop over all students records.
    for e in lines :
        
        #Start at line 2 
        if i % 2 == 0 and i != 0 :
            line = e
            line = line.split()
            
            #Calculate the homework mark. 5%
            HW = 0
            HW1 = 0
            HW2 = 0
            HW3 = 0
            HW4 = 0
            
            if line[2] != "-" :
                HW1 = int(line[2])
                
            if line[3] != "-" :
                HW2 = int(line[3])
                
            if line[4] != "-" :
                HW3 = int(line[4])
                
            if line[5] != "-" :
                HW4 = int(line[5])
                
            HW = round(((HW1 + HW2 + HW3 + HW4) / 400) * 5, 3)
            
            
            #Calculate the mid term exam mark. 30%
            MID = 0
            if line[6] != "-" :
                MID = int(line[6])
                
            MID = (MID / 100) * 30
            
            #Calculate the final exam mark. 30%
            Final = 0 
            if line[7] != "-" :
                Final = int(line[7])
            
            Final = (Final / 100) * 30
            
            #taking best 4 quizzes from the quiz file. 15%
            Quizzes = 0
            infile = open("Quizzes.txt", "r")
            
            while True :
                quizline = infile.readline()
                quizline = quizline.split()
                if line[1] in quizline :
                    if quizline[7] != '-' :                       
                        Quizzes = quizline[7]
                    break
            
            infile.close
            
            #Taking student marks from lab marks file 
            labline = ""
            infile = open("Lab_Marks.txt", "r")
            lablines = infile.readlines()            
            infile.close
            
            #Finding the row with student ID
            for l in lablines :  
                if line[1] in l :
                    labline = l.split()
                    break

            #Calculating the lab work mark. 3%
            LB = 0
            LB1 = 0
            LB2 = 0 
            LB3 = 0
            LB4 = 0

            if labline[2] != "-" :
                LB1 = int(labline[2])
                
            if labline[3] != "-" :
                LB2 = int(labline[3])
                
            if labline[4] != "-" :
                LB3 = int(labline[4])
                
            if labline[5] != "-" :
                LB4 = int(labline[5])
                
            LB = round(((LB1 + LB2 + LB3 + LB4) / 400) * 3, 3)
            
            #Calculating lab exam mark. 12%
            LabExam = 0
            LabExam1 = 0
            LabExam2 = 0
            
            if labline[6] != "-" :
                LabExam1 = int(labline[6])
                
            if labline[7] != "-" :
                LabExam2 = int(labline[7])
                
            LabExam = round((((LabExam1 + LabExam2) /200) * 12),3)
            
            #Calculating lab project mark. 5%
            LBProject = 0
            if labline[8] != "-" :
                LBProject = int(labline[8])
            
            LBProject = round(((LBProject / 100 )* 5), 3)
            
            #Adding all the marks. 100%
            Totalmark = round(float(LB) + float(LBProject) + float(LabExam) + float(HW) + float(Quizzes) + float(MID) + float(Final), 3)
            
            #Adds the total mark to allmarks list to return after the function is over.
            allmarks.append(Totalmark)
            
            #Using the total mark to calculate the letter grade.
            Lettergrade = ""
            if Totalmark >= 95 and Totalmark <= 100 :
                Lettergrade = "A+"
            elif Totalmark >= 90 and Totalmark < 95 :
                Lettergrade = "A"
            elif Totalmark >= 85 and Totalmark < 90 :
                Lettergrade = "B+"
            elif Totalmark >= 80 and Totalmark < 85 :
                Lettergrade = "B"
            elif Totalmark >= 75 and Totalmark < 80 :
                Lettergrade = "C+"
            elif Totalmark >= 70 and Totalmark < 75 :
                Lettergrade = "C"
            elif Totalmark >= 65 and Totalmark < 70 :
                Lettergrade = "D+"
            elif Totalmark >= 60 and Totalmark < 65 :
                Lettergrade = "D"
            else :
                Lettergrade = "F"
            
            #Adds the student name, id, and total mark to the finalmark variable. 
            fm = line[0] + " " + line[1] + " " + str(Totalmark)
            
            #Save another list with total marks to use to write students with best to worst.
            finalmarks.append(fm)
            
            #Adds the totalmark to studentmark variable
            studentmark.append(Totalmark)
            
            #Using if statement to find students with grade higher than B+ and saving them in Beststudents list.
            if Lettergrade == "A+" or Lettergrade == "A" :
                student = "Student: " + line[0] + " with the ID: " + line[1] + " got the grade " + Lettergrade 
                Beststudents.append(student)
            
            #print("Total mark for", line[0], "ID:", line[1], "is", Totalmark, "(" + Lettergrade + ")") 
            
            #Saving all rows in the grades file.
            infile = open("Grades.txt", "r")
            gradelines = infile.readlines()
            infile.close

            row = ""
            linenum = 0
            i = 0
            #Saving the row in the Grade file with the same student ID
            for e in gradelines :
                if line[1] in e :
                    row = e
                    linenum = i
                i += 1
                
            #Position in the file where the grade letter would be entered.      
            position = 28  
            Letter = Lettergrade
            
            #Checks the length of the grade letter then adds the mark to the row with the student ID saved in a variable.
            if len(Lettergrade) == 2 :
                Lettergrade =  " " + Lettergrade
            
            elif len(Lettergrade) == 1 :
                Lettergrade = " " + Lettergrade + " "
   
            record = row[0 : position-1] + Lettergrade + row[position + 2 :]
            
            #Updating the Grades file.
            outfile = open("Grades.txt", "w")
            
            #Adding grade depending the letter grade.
            grade = ""
            if Letter == "A+" :
                grade = "Exceptional"
            elif Letter == "A" :
                grade = "Excellent"
            elif Letter == "B+" :
                grade = "Superior"
            elif Letter == "B" :
                grade = "Very Good"
            elif Letter == "C+" :
                grade = "Above Average"
            elif Letter == "C" :
                grade = "Good"
            elif Letter == "D+" :
                grade = "High Pass"
            elif Letter == "D" :
                grade = "Pass"
            else :
                grade = "Fail"
            
            #Position in the file where the grade would be entered.
            gradeposition = 35
            
            graderecord = record[0 : gradeposition-1] + grade + "   \n"
            
            #Readding the rows back to the grades file with the updated row.
            outfile = open("Grades.txt", "w")
            i = 0
            for g in gradelines :
                if i == linenum :
                    outfile.write(graderecord)
                else :
                    outfile.write(g)
                i += 1
            outfile.close()
        i += 1
    
    #Saving the first and second lines in their own variables, and the rest of the lines in one variable.
    infile = open("Finalresult.txt", "r")
    firstline = infile.readline()
    secondline = infile.readline()
    allrows = infile.readlines()
    length = len(allrows)
    infile.close
    
    #Write first than second lines.
    outfile = open("Finalresult.txt", "w")
    outfile.write(firstline)
    outfile.write(secondline)
    
    #Write student marks from best to worst.
    for e in range(0, length) :
        highest = studentmark
        if e % 2 == 0 :
            maximum = max(highest)
            value = highest.index(maximum)
            string = str(finalmarks[value]).split()
            mark_row = string[0]
            name = 13 - len(string[0])
            i = 0
            while i < name :
                mark_row += " "
                i += 1
            mark_row += string[1]
            ID = 13 - len(string[1])
            i = 0
            while i < ID :
                mark_row += " "
                i += 1
            mark_row += string[2]

            outfile.write(mark_row + "\n")
            highest.pop(value)
            finalmarks.pop(value)
        else :
            outfile.write(secondline)
    outfile.close()
            
    return allmarks, Beststudents
    
# main method
def main():
    while True :
        # define the numbers from 1 to 5 matched with lecture files

        print("---Lecture Assessments--")
        print("Lecture Attendance   (1)")
        print("Homework Assignments (2)")
        print("Quizzes              (3)")
        print("Midterm Exam         (4)")
        print("Final Exam           (5)")
        print()
        # define the numbers from 6 to 8 matched with lab files
    
        print("----Lab Assessments-----")
        print("Lab Attendance       (6)")
        print("Lab Work             (7)")
        print("Lab Exam             (8)")
        print("Lab Project          (9)")
        print()
        print("--- Enter Nothing to end the program and give the results ---")
        print()
        # ask the user to enter number to select which file he would modify
        Assessment = input("Select a grading criteria by entering its number: ")
    
        # check the number entered by the user
        if Assessment == "1" :
            Lecture_Attendence(Assessment)
        elif Assessment == "2" :
            Homework_Assignments()
        elif Assessment == "3":
            Quizzes(Assessment)
        elif Assessment == "4" :
            Midterm_Exam()
        elif Assessment == "5" :
            Final_Exam()
        elif Assessment == "6":
            Lab_Attendance(Assessment)
        elif Assessment == "7" :
            Lab_Work()
        elif Assessment == "8" :
            Lab_Exam()
        elif Assessment == "9":
            Lab_project()
        elif Assessment == "" : 
            #getGrade() 
        
            #Call Grades function to calculate total student marks, while saving best students in high, and students total marks in marks.
            marks, high = Grades()
            print()
            #print best students
            print("Students with a grade higher than B+:")
            for e in high :
                print(e)
            print()
            #print best, worst, and average.
            print("Best mark:", max(marks))
            print("worst mark:",min(marks))
            sum = 0
            count = 0
            for e in marks :
                sum += e
                count += 1
            print("The average is:", round(sum / count, 3))
            break
            
        else :
            print("Wrong Input")
            print()
            print()
            
main()
# Out:
# ---Lecture Assessments--
# Lecture Attendance   (1)
# Homework Assignments (2)
# Quizzes              (3)
# Midterm Exam         (4)
# Final Exam           (5)
#
# ----Lab Assessments-----
# Lab Attendance       (6)
# Lab Work             (7)
# Lab Exam             (8)
# Lab Project          (9)
#
# --- Enter Nothing to end the program and give the results ---
#
# Select a grading criteria by entering its number: 3
# Enter Student ID: s202323003
# Enter 1 to add Quiz1 mark, 2 for Quiz2, 3 for Quiz3, 4 for Quiz4, 5 for Quiz5: 3
# Quiz Number is: 3 The mark is: 100
# Enter the mark you want to Modify: 100
#
# Best 4 Quizzes are:  [100, 100, 100, 100]
# The Quiz mark out of 15 is: 15.0/15
# Enter Student ID:
# ---Lecture Assessments--
# Lecture Attendance   (1)
# Homework Assignments (2)
# Quizzes              (3)
# Midterm Exam         (4)
# Final Exam           (5)
#
# ----Lab Assessments-----
# Lab Attendance       (6)
# Lab Work             (7)
# Lab Exam             (8)
# ...
